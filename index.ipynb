# %%
from IPython.core.display import HTML
HTML("""
<style>
body{background: #1ED4E5; !important}

#cd-timeline {
  position: relative;
  padding: 2em 0;
}
#cd-timeline::before {
  /* this is the vertical line */
  content: '';
  position: absolute;
  top: 0;
  left: 49%;
  height: 5000em;
  width: 4px;
  background: #1ED4E5;
  margin-top:2.5em;
}

.cd-timeline-content{
    position: relative;
    float:left;
    clear:right;
    width:45%;
    margin-bottom:2em;
}

/*.cd-timeline-content.left{
}*/


.cd-timeline-content.right{
    margin-left: 9%;
    text-align:right;
    margin-bottom:2em;
    margin-left: 0%;
}

.cd-timeline-content.right p, .cd-timeline-content.right h1,.cd-timeline-content.right a{
    text-align:right;
}

.cd-timeline-content.right a.anchor-link{
  display: none;
}

.cd-timeline-img{
    position: relative;
    width:5%;
    float: left;
    
}

.cd-timeline-img.left{
  margin-left:46.9%;
    margin-right:2%;
    clear:left;
}

.cd-timeline-img.right{
    margin-left: 2%;
    clear:right;
}
</style>
<script>
code_show=true; 
function code_toggle() {
 $('div.input').hide();
 $('div.output').hide();
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
""")
# Out:
# <style>
# body{background: #1ED4E5; !important}
#
# #cd-timeline {
#   position: relative;
#   padding: 2em 0;
# }
# #cd-timeline::before {
#   /* this is the vertical line */
#   content: '';
#   position: absolute;
#   top: 0;
#   left: 49%;
#   height: 5000em;
#   width: 4px;
#   background: #1ED4E5;
#   margin-top:2.5em;
# }
#
# .cd-timeline-content{
#     position: relative;
#     float:left;
#     clear:right;
#     width:45%;
#     margin-bottom:2em;
# }
#
# /*.cd-timeline-content.left{
# }*/
#
#
# .cd-timeline-content.right{
#     margin-left: 9%;
#     text-align:right;
#     margin-bottom:2em;
#     margin-left: 0%;
# }
#
# .cd-timeline-content.right p, .cd-timeline-content.right h1,.cd-timeline-content.right a{
#     text-align:right;
# }
#
# .cd-timeline-content.right a.anchor-link{
#   display: none;
# }
#
# .cd-timeline-img{
#     position: relative;
#     width:5%;
#     float: left;
#
# }
#
# .cd-timeline-img.left{
#   margin-left:46.9%;
#     margin-right:2%;
# ...

# %% [markdown]
# <section id="cd-timeline">
# <div class="cd-timeline-block">
# <div class="cd-timeline-img left">
# <img src="notebooks/images/rootlogo.png" alt="Picture">
# </div> <!-- cd-timeline-img -->
# <div class="cd-timeline-content left">
# <h2>1 Motivation and Introduction</h2>
# <p>Why did we create the ROOT Primer? What will you learn from reading it? The first chapter will answer these questions for you.</p>
# <a href="notebooks/1-Motivation-and-Introduction.ipynb" class="cd-read-more">Take me there! </a>
# </div> <!-- cd-timeline-content -->
# </div> <!-- cd-timeline-block -->
#
# <div class="cd-timeline-block">
#
# <div class="cd-timeline-content right">
# <h2>2 ROOT Basics</h2>
# <p>Let's dive right in. In the second chapter you will learn all the nessecary comands to create your first plots. Edit the code provided and re-run the notebook in order to get new results. Additionally you can manipulate the plots o your screen and save them as an image.
# </p>
# <a href="notebooks/2-ROOT-Basics.ipynb" class="cd-read-more">Take me there!</a>
# </div> <!-- cd-timeline-content -->
# <div class="cd-timeline-img right">
# <img src="notebooks/images/rootlogo.png" alt="Picture">
# </div> <!-- cd-timeline-img -->
# </div> <!-- cd-timeline-block -->
#
#
# <div class="cd-timeline-block">
# <div class="cd-timeline-img left">
# <img src="notebooks/images/rootlogo.png" alt="Picture">
# </div> <!-- cd-timeline-img -->
# <div class="cd-timeline-content left">
# <h2>3 ROOT Macros</h2>
# <p>By now you know enough to start using ROOT and there is more. In chapter three you will master how to create ROOT macros and re-use your code with different data sets.</p>
# <a href="notebooks/3-ROOT-Macros.ipynb" class="cd-read-more">Take me there!</a>
# </div> <!-- cd-timeline-content -->
# </div> <!-- cd-timeline-block -->
#
# <div class="cd-timeline-block">
# <div class="cd-timeline-content right">
# <h2>4 Graphs</h2>
# <p>
# <a href="notebooks/4-Graphs.ipynb" class="cd-read-more"><img src="notebooks/images/Chapter4.png" alt="Chapter 4" style="margin:auto; width:300px;"></a>
# Now it get's impressive! This chapter will show you how to exploit ROOT functionalities to create complicated graphs with errors like this one.</p>
# <a href="notebooks/4-Graphs.ipynb" class="cd-read-more">Take me there!</a>
# </div> <!-- cd-timeline-content -->
# <div class="cd-timeline-img right">
# <img src="notebooks/images/rootlogo.png" alt="Picture">
# </div> <!-- cd-timeline-img -->
# </div> <!-- cd-timeline-block -->
#
# <div class="cd-timeline-block">
# <div class="cd-timeline-img left">
# <img src="notebooks/images/rootlogo.png" alt="Picture">
# </div> <!-- cd-timeline-img -->
# <div class="cd-timeline-content left">
# <h2>5 Histograms</h2>
# <p>Histograms are powerfull tools for measurements visualisation and data reduction. In this chapter will find out how to create ni- and bi- dimensional histograms with ROOT.
# <a href="notebooks/5-Histograms.ipynb" class="cd-read-more"><img src="notebooks/images/Chapter5.png" alt="Chapter 4" style="margin:auto; width:300px;"></a></p>
# <a href="notebooks/5-Histograms.ipynb" class="cd-read-more">Take me there!</a>
# </div> <!-- cd-timeline-content -->
# </div> <!-- cd-timeline-block -->
#
# <div class="cd-timeline-block">
# <div class="cd-timeline-content right">
# <h2>6 Functions and Parameter Estimation</h2>
# <p>Danilo please add information here!!!</p>
# <a href="notebooks/6-Functions-and-Parameter-Estimation.ipynb" class="cd-read-more">Take me there!</a>
# </div> <!-- cd-timeline-content -->
# <div class="cd-timeline-img right">
# <img src="notebooks/images/rootlogo.png" alt="Picture">
# </div> <!-- cd-timeline-img -->
# </div> <!-- cd-timeline-block -->
#
# <div class="cd-timeline-block">
# <div class="cd-timeline-img left">
# <img src="notebooks/images/rootlogo.png" alt="Picture">
# </div> <!-- cd-timeline-img -->
# <div class="cd-timeline-content left">
# <h2>7 File IO and Parallel Analysis</h2>
# <p>You created beautiful and informative graphs in all of the previous sections, now it is time to store them!
# </p>
# <a href="notebooks/7-File-IO-and-Parallel-Analysis.ipynb" class="cd-read-more">Take me there!</a>
# </div> <!-- cd-timeline-content -->
# </div> <!-- cd-timeline-block -->
#
# <div class="cd-timeline-block">
# <div class="cd-timeline-content right">
# <h2>8 ROOT in Python</h2>
# <p>Maybe you are more comfortable with Python than with C++? ROOT offers a set of bindings called PyROOT, in order to interface to Python. Go through this chapter and learn how to use it. </p>
# <a href="notebooks/8-ROOT-in-Python.ipynb" class="cd-read-more">Take me there!</a>
# </div> <!-- cd-timeline-content -->
# <div class="cd-timeline-img right">
# <img src="notebooks/images/rootlogo.png" alt="Picture">
# </div> <!-- cd-timeline-img -->
# </div> <!-- cd-timeline-block -->
#
#
# <div class="cd-timeline-block">
# <div class="cd-timeline-img left">
# <img src="notebooks/images/rootlogo.png" alt="Picture">
# </div> <!-- cd-timeline-img -->
# <div class="cd-timeline-content left">
# <h2>9 Concluding Remarks</h2>
# <p>This tutorial came to an end. Read this chapter to get more resources and documentation about ROOT. </p>
# <a href="notebooks/9-Concluding-Remarks.ipynb" class="cd-read-more">Take me there!</a>
# </div> <!-- cd-timeline-content -->
# </div> <!-- cd-timeline-block -->
# </section>
